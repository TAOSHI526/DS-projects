# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly as py
# %matplotlib inline
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import cufflinks as cf
cf.go_offline()
import matplotlib.pyplot as plt
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df = pd.read_csv('happy.csv')

# %%
df.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# 1                      23.0
# 2                      12.0
# 3                      13.0
# 4                      18.0

# %%
df.columns = ['country', 'ladder', 'ladder_sd', 'positive_affect', 'negative_affect', 'social_support', 'freedom', 'corruption', 'generosity', 'gdp_per_capita', 'healthy_life_expectancy']

# %%
df.head(5)
# Out:
#        country  ladder  ladder_sd  positive_affect  negative_affect  \
# 0      Finland       1          4             41.0             10.0
# 1      Denmark       2         13             24.0             26.0
# 2       Norway       3          8             16.0             29.0
# 3      Iceland       4          9              3.0              3.0
# 4  Netherlands       5          1             12.0             25.0
#
#    social_support  freedom  corruption  generosity  gdp_per_capita  \
# 0             2.0      5.0         4.0        47.0            22.0
# 1             4.0      6.0         3.0        22.0            14.0
# 2             3.0      3.0         8.0        11.0             7.0
# 3             1.0      7.0        45.0         3.0            15.0
# 4            15.0     19.0        12.0         7.0            12.0
#
#    healthy_life_expectancy
# 0                     27.0
# 1                     23.0
# 2                     12.0
# 3                     13.0
# 4                     18.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 11 columns):
# country                    156 non-null object
# ladder                     156 non-null int64
# ladder_sd                  156 non-null int64
# positive_affect            155 non-null float64
# negative_affect            155 non-null float64
# social_support             155 non-null float64
# freedom                    155 non-null float64
# corruption                 148 non-null float64
# generosity                 155 non-null float64
# gdp_per_capita             152 non-null float64
# healthy_life_expectancy    150 non-null float64
# dtypes: float64(8), int64(2), object(1)
# memory usage: 13.5+ KB

# %% [markdown]
# ## Adding a continent column

# %%
asia = ["Israel", "United Arab Emirates", "Singapore", "Thailand", "Taiwan Province of China",
                 "Qatar", "Saudi Arabia", "Kuwait", "Bahrain", "Malaysia", "Uzbekistan", "Japan",
                 "South Korea", "Turkmenistan", "Kazakhstan", "Turkey", "Hong Kong S.A.R., China", "Philippines",
                 "Jordan", "China", "Pakistan", "Indonesia", "Azerbaijan", "Lebanon", "Vietnam",
                 "Tajikistan", "Bhutan", "Kyrgyzstan", "Nepal", "Mongolia", "Palestinian Territories",
                 "Iran", "Bangladesh", "Myanmar", "Iraq", "Sri Lanka", "Armenia", "India", "Georgia",
                 "Cambodia", "Afghanistan", "Yemen", "Syria"]
europe = ["Norway", "Denmark", "Iceland", "Switzerland", "Finland",
                 "Netherlands", "Sweden", "Austria", "Ireland", "Germany",
                 "Belgium", "Luxembourg", "United Kingdom", "Czech Republic",
                 "Malta", "France", "Spain", "Slovakia", "Poland", "Italy",
                 "Russia", "Lithuania", "Latvia", "Moldova", "Romania",
                 "Slovenia", "North Cyprus", "Cyprus", "Estonia", "Belarus",
                 "Serbia", "Hungary", "Croatia", "Kosovo", "Montenegro",
                 "Greece", "Portugal", "Bosnia and Herzegovina", "Macedonia",
                 "Bulgaria", "Albania", "Ukraine"]
north_america = ["Canada", "Costa Rica", "United States", "Mexico",  
                 "Panama","Trinidad and Tobago", "El Salvador", "Belize", "Guatemala",
                 "Jamaica", "Nicaragua", "Dominican Republic", "Honduras",
                 "Haiti"]
south_america = ["Chile", "Brazil", "Argentina", "Uruguay",
                 "Colombia", "Ecuador", "Bolivia", "Peru",
                 "Paraguay", "Venezuela"]
australia = ["New Zealand", "Australia"]
d_asia = dict.fromkeys(asia, 'Asia')
d_europe = dict.fromkeys(europe, 'Europe')
d_north_america = dict.fromkeys(north_america, 'North America')
d_south_america = dict.fromkeys(south_america, 'South America')
d_australia = dict.fromkeys(australia, 'Australia')
continent_dict = {**d_asia, **d_europe, **d_north_america, **d_south_america, **d_australia}
df["continent"] = df["country"].map(continent_dict)
df.continent.fillna("Africa", inplace=True)

# %%
df.head()
# Out:
#        country  ladder  ladder_sd  positive_affect  negative_affect  \
# 0      Finland       1          4             41.0             10.0
# 1      Denmark       2         13             24.0             26.0
# 2       Norway       3          8             16.0             29.0
# 3      Iceland       4          9              3.0              3.0
# 4  Netherlands       5          1             12.0             25.0
#
#    social_support  freedom  corruption  generosity  gdp_per_capita  \
# 0             2.0      5.0         4.0        47.0            22.0
# 1             4.0      6.0         3.0        22.0            14.0
# 2             3.0      3.0         8.0        11.0             7.0
# 3             1.0      7.0        45.0         3.0            15.0
# 4            15.0     19.0        12.0         7.0            12.0
#
#    healthy_life_expectancy continent
# 0                     27.0    Europe
# 1                     23.0    Europe
# 2                     12.0    Europe
# 3                     13.0    Europe
# 4                     18.0    Europe

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(), cmap="RdYlBu")
plt.tight_layout()
plt.savefig('t_corr.pdf')

# %% [markdown]
# ## Life expectancy accross the globe

# %%
data = dict(type = 'choropleth', 
           locations = df['country'],
           locationmode = 'country names',
           z = df['ladder'], 
           text = df['country'],
           colorbar = {'title':'Ladder'},
           colorscale = "Blues")
layout = dict(title = 'Life satisfaction ladder 2019', 
             geo = dict(showframe = False, 
                       projection = {'type': 'equirectangular'}))
choromap = go.Figure(data = [data], layout=layout)
#iplot(choromap)
py.offline.init_notebook_mode(connected=True)
py.offline.plot(choromap, filename='map1.html', auto_open=False)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 'map1.html'

# %%
p = sns.color_palette(["mediumseagreen", "sandybrown", "royalblue", "orangered", "saddlebrown", "darkorchid"])

# %%
sns.boxplot(x="ladder", y="continent", data=df, palette=p)
plt.tight_layout()
plt.savefig('box.pdf')

# %%
asia = df[df.continent=="Asia"]
north_america = df[df.continent=="North America"]

# %% [markdown]
# ## How gdp per capita plays a role in all of these factors in North America

# %%
sns.pairplot(north_america[['gdp_per_capita', 'freedom', 'healthy_life_expectancy', 'ladder', 'continent']], hue='continent', palette="Blues")

# %%
##Correlation between freedom and life satisfaction in Asia

# %%
scatter1 = asia.iplot(kind='scatter', mode='markers',
                      x='freedom', y='ladder', text='country', color='orangered',
                      xTitle='Freedom', yTitle='Ladder',asFigure=True)
# scatter1.write_html('first_figure.html', auto_open=True)
py.offline.init_notebook_mode(connected=True)


py.offline.plot(scatter1, filename='scatter1.html', auto_open=False)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 'scatter1.html'

# %%
data = dict(type = 'choropleth', 
           locations = df['country'],
           locationmode = 'country names',
           z = df['freedom'], 
           text = df['country'],
           colorbar = {'title':'Ladder'},
           colorscale = 'Reds')
layout = dict(title = 'Countries With Least Freedom', 
             geo = dict(showframe = False, 
                       projection = dict(type = 'equirectangular')))
choromap = go.Figure(data = [data], layout=layout)
# iplot(choromap)

import plotly as py
py.offline.init_notebook_mode(connected=True)
# py.offline.iplot(choromap, filename='myplot.html')
py.offline.plot(choromap, filename='map2.html', auto_open=False)
#py.plot(choromap,filename='sampleplot.html')
# plotly.offline.plot(choromap, filename = 'filename.html', auto_open=False)
#plotly.offline.plot(choromap, filename='map2.html')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# 'map2.html'

# %%
df2 = pd.read_csv('press_freedom.csv')

# %%
df2
# Out:
#      ISO  Rank2019          FR_Country                             EN_country  \
# 0    NOR         1             Norvège                                 Norway
# 1    FIN         2            Finlande                                Finland
# 2    SWE         3               Suede                                 Sweden
# 3    NLD         4            Pays-Bas                            Netherlands
# 4    DNK         5            Danemark                                Denmark
# 5    CHE         6              Suisse                            Switzerland
# 6    NZL         7    Nouvelle-Zélande                            New Zealand
# 7    JAM         8            Jamaïque                                Jamaica
# 8    BEL         9            Belgique                                Belgium
# 9    CRI        10          Costa Rica                             Costa Rica
# 10   EST        11             Estonie                                Estonia
# 11   PRT        12            Portugal                               Portugal
# 12   DEU        13           Allemagne                                Germany
# 13   ISL        14             Islande                                Iceland
# 14   IRL        15             Irlande                                Ireland
# 15   AUT        16            Autriche                                Austria
# 16   LUX        17          Luxembourg                             Luxembourg
# 17   CAN        18              Canada                                 Canada
# 18   URY        19             Uruguay                                Uruguay
# 19   SUR        20             Surinam                               Suriname
# 20   AUS        21           Australie                              Australia
# 21   WSM        22               Samoa                                  Samoa
# 22   NAM        23             Namibie                                Namibia
# 23   LVA        24            Lettonie                                 Latvia
# 24   CPV        25            Cap-Vert                             Cape Verde
# 25   LIE        26       Liechtenstein                          Liechtenstein
# 26   GHA        27               Ghana                                  Ghana
# 27   CYP        28              Chypre                                 Cyprus
# 28   ESP        29             Espagne                                  Spain
# 29   LTU        30            Lituanie                              Lithuania
# ..   ...       ...                 ...                                    ...
# 150  SGP       151           Singapour                              Singapore
# 19          21      16,44       Amériques                      سورينام
# 20          19      15,46  Asie-Pacifique                     أستراليا
# 21          22      16,69  Asie-Pacifique                        ساموا
# 22          26      20,24         Afrique                      ناميبيا
# 23          24      19,63      UE Balkans                       لاتفيا
# 24          29      20,39         Afrique                 الرأس الأخضر
# 25          30      20,49      UE Balkans                   ليختنشتاين
# 26          23      18,41         Afrique                         غانا
# 27          25      19,85      UE Balkans                         قبرص
# 28          31      20,51      UE Balkans                      إسبانيا
# 29          36       22,2      UE Balkans                     ليتوانيا
# ..         ...        ...             ...                          ...
# 150        151      50,95  Asie-Pacifique                     سنغافورة
# 151        153      51,48  Asie-Pacifique                       بروناي
# 152        155      52,59            EEAC                روسيا البيضاء
# 153        154       51,6         Afrique  جمهورية الكونغو الديمقراطية
# 154        156       52,9         Afrique                       رواندا
# 155        160      56,56            MENA                       العراق
# 156        157       53,5            EEAC                        تركيا
# 157        158      54,41            EEAC                    كازاخستان
# 158        159      55,26         Afrique                      بوروندي
# 159        165      60,84            EEAC                    أوزبكستان
# 160        149      50,06            EEAC                    طاجيكستان
# 161        162      56,79            MENA                        ليبيا
# 162        161      56,72            MENA                          مصر
# 163        168      63,04         Afrique                      الصومال
# 164        171      66,47         Afrique             غينيا الاستوائية
# 165        163      59,73            EEAC                     أذربيجان
# 166        166      60,85            MENA                      البحرين
# 167        167      62,23            MENA                        اليمن
# 168        172       68,9       Amériques                         كوبا
# 169        164      60,71            MENA                        إيران
# 170        170      66,41  Asie-Pacifique                         لاوس
# 171        169      63,13            MENA     المملكة العربية السعودية
# 172        173      70,77         Afrique                       جيبوتي
# 173        177      79,22            MENA                        سوريا
# 174        174      71,13         Afrique                      السودان
# 175        175      75,05  Asie-Pacifique                       فيتنام
# 176        176      78,29  Asie-Pacifique                        الصين
# 177        179      84,24         Afrique                      إريتريا
# 178        180      88,87  Asie-Pacifique               كوريا الشمالية
# 179        178       84,2            EEAC                   تركمانستان
#
#                FA_country
# 0                    نروژ
# 1                  فنلاند
# 2                    سوئد
# 3                    هلند
# 4                 دانمارک
# 5                   سويیس
# 6                زلاند نو
# 7                جامائیکا
# 8                   بلژیک
# 9               کاستاریکا
# 10                 استونی
# 11                 پرتغال
# 12                  آلمان
# 13                 ایسلند
# 14                 ایرلند
# 15                  اتریش
# 16             لوکزامبورگ
# 17                 کانادا
# 18                اروگويه
# 19                سورینام
# 20               استرالیا
# 21                  ساموآ
# 22                نامیبیا
# 23                 لتوانی
# 24                 کیپورد
# 25           لیختن‌اشتاین
# 26                    غنا
# 27                   قبرس
# 28                اسپانیا
# 29                لیتوانی
# ..                    ...
# 150               سنگاپور
# 151                 برونی
# 152            روسیه سفید
# 153  جمهوری دمکراتیک کنگو
# 154                 روندا
# 155                  عراق
# 156                 ترکیه
# 157              قزاقستان
# 158                بروندی
# 159             اوزبکستان
# 160             تاجیکستان
# 161                  لیبی
# 162                   مصر
# 163                سومالی
# 164          گینه اکوادور
# 165             آذربایجان
# 166                 بحرین
# 167                   یمن
# 168                  کوبا
# 169                 ایران
# 170                 لائوس
# 171         عربستان سعودی
# 172                جیبوتی
# 173                 سوریه
# 174                 سودان
# 175                ویتنام
# 176                   چین
# 177                اریتره
# 178             کره شمالی
# 179             ترکمنستان
#
# [180 rows x 14 columns]

# %%
df2 = df2.drop(columns = ['ISO','FR_Country','ES_country','Score A','Sco Exa','Score 2019','Progression RANK','Rank 2018','Score 2018','Zone','AR_country','FA_country'])

# %%
df2
# Out:
#      Rank2019                             EN_country
# 0           1                                 Norway
# 1           2                                Finland
# 2           3                                 Sweden
# 3           4                            Netherlands
# 4           5                                Denmark
# 5           6                            Switzerland
# 6           7                            New Zealand
# 7           8                                Jamaica
# 8           9                                Belgium
# 9          10                             Costa Rica
# 10         11                                Estonia
# 11         12                               Portugal
# 12         13                                Germany
# 13         14                                Iceland
# 14         15                                Ireland
# 15         16                                Austria
# 16         17                             Luxembourg
# 17         18                                 Canada
# 18         19                                Uruguay
# 19         20                               Suriname
# 20         21                              Australia
# 21         22                                  Samoa
# 22         23                                Namibia
# 23         24                                 Latvia
# 24         25                             Cape Verde
# 25         26                          Liechtenstein
# 26         27                                  Ghana
# 27         28                                 Cyprus
# 28         29                                  Spain
# 29         30                              Lithuania
# ..        ...                                    ...
# 150       151                              Singapore
# 151       152                      Brunei Darussalam
# 152       153                                Belarus
# 153       154   The Democratic Republic Of The Congo
# 154       155                                 Rwanda
# 155       156                                   Iraq
# 156       157                                 Turkey
# 157       158                             Kazakhstan
# 158       159                                Burundi
# 159       160                             Uzbekistan
# 160       161                             Tajikistan
# 161       162                                  Libya
# 162       163                                  Egypt
# 163       164                                Somalia
# 164       165                      Equatorial Guinea
# 165       166                             Azerbaijan
# 166       167                                Bahrain
# 167       168                                  Yemen
# 168       169                                   Cuba
# 169       170               Islamic Republic of Iran
# 170       171       Lao People's Democratic Republic
# 171       172                           Saudi Arabia
# 172       173                               Djibouti
# 173       174                   Syrian Arab Republic
# 174       175                                  Sudan
# 175       176                                Vietnam
# 176       177                                  China
# 177       178                                Eritrea
# 178       179  Democratic People's Republic of Korea
# 179       180                           Turkmenistan
#
# [180 rows x 2 columns]

# %%
df = pd.merge(left=df, right=df2, left_on='country', right_on='EN_country')

# %%
df=df.drop(columns=['EN_country'])

# %% [markdown]
# ## Correlation between press freedom index and happiness index

# %%
sns.jointplot("Rank2019", "ladder", data=df, kind='reg', color='orangered')
plt.ylim(-25, 175)
plt.xlim(-25, 200)
plt.tight_layout()
plt.savefig('press_happiness.pdf')

# %%
sns.jointplot("Rank2019", "corruption", data=df, kind='reg', color='orangered')
plt.ylim(-25, 175)
plt.xlim(-25, 200)
# Out:
# (-25, 200)

# %%
df3 = df.sort_values('freedom').reset_index().drop(columns=['index'])

# %%
df3.head()
# Out:
#                 country  ladder  ladder_sd  positive_affect  negative_affect  \
# 0            Uzbekistan      41         99             19.0             15.0
# 1              Cambodia     109        135             27.0            142.0
# 2                Norway       3          8             16.0             29.0
# 3  United Arab Emirates      21         65             43.0             56.0
# 4               Finland       1          4             41.0             10.0
#
#    social_support  freedom  corruption  generosity  gdp_per_capita  \
# 0            11.0      1.0        18.0        29.0           104.0
# 1           109.0      2.0        94.0        61.0           116.0
# 2             3.0      3.0         8.0        11.0             7.0
# 3            72.0      4.0         NaN        15.0             4.0
# 4             2.0      5.0         4.0        47.0            22.0
#
#    healthy_life_expectancy continent  Rank2019
# 0                     83.0      Asia       160
# 1                    102.0      Asia       143
# 2                     12.0    Europe         1
# 3                     60.0      Asia       133
# 4                     27.0    Europe         2

# %%
df3 = df3.drop(columns = ['ladder','ladder_sd','positive_affect','negative_affect','social_support','freedom', 'corruption','generosity','gdp_per_capita','healthy_life_expectancy','continent','Rank2019'])

# %%
df3['free_rank']=df3.index+1

# %%
df3
# Out:
#                       country  free_rank
# 0                  Uzbekistan          1
# 1                    Cambodia          2
# 2                      Norway          3
# 3        United Arab Emirates          4
# 4                     Finland          5
# 5                     Denmark          6
# 6                     Iceland          7
# 7                 New Zealand          8
# 8                      Canada          9
# 9                      Sweden         10
# 10                Switzerland         11
# 11                      Malta         12
# 12                   Slovenia         13
# 13                    Somalia         14
# 14                Philippines         15
# 15                 Costa Rica         16
# 16                  Australia         17
# 17                   Thailand         18
# 18                Netherlands         19
# 19                  Singapore         20
# 20                     Rwanda         21
# 21                    Vietnam         22
# 22                    Bahrain         23
# 23                  Guatemala         24
# 24                    Austria         25
# 25                 Bangladesh         26
# 26                 Luxembourg         27
# 27                    Myanmar         28
# 28                    Uruguay         29
# 29                      China         30
# ..                        ...        ...
# 117                   Armenia        118
# 118                    Serbia        119
# 119                    Latvia        120
# 120              Burkina Faso        121
# 121                   Moldova        122
# 122                     Egypt        123
# 123                      Iraq        124
# 124                   Belarus        125
# 125                     Italy        126
# 126  Central African Republic        127
# 127                   Burundi        128
# 128                   Lebanon        129
# 129                   Hungary        130
# 130                Montenegro        131
# 131                    Turkey        132
# 132                   Ukraine        133
# 133                      Chad        134
# 134                   Tunisia        135
# 135               South Korea        136
# 136                 Venezuela        137
# 137                Madagascar        138
# 138                     Yemen        139
# 139                   Comoros        140
# 140                   Algeria        141
# 141                    Greece        142
# 142                Mauritania        143
# 143                     Haiti        144
# 144               South Sudan        145
# 145               Afghanistan        146
# 146                     Qatar        147
#
# [147 rows x 2 columns]

# %%
df=pd.merge(left=df, right=df3, left_on='country', right_on='country')

# %%
sns.jointplot("Rank2019", "free_rank", data=df, kind='reg', color='orangered')
plt.ylim(-25, 175)
plt.xlim(-25, 200)
plt.tight_layout()
plt.savefig('pressf_f.pdf')
